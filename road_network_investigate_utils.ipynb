# %%
import osmnx as ox
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from utils import data_loader, display
# %matplotlib inline

# %%
path = 'result/seg/粤B0AA56_101.csv'
road_path = pd.read_csv(path)
# road_network = data_loader.load_drive_graph()
# ox.io.save_graphml(road_network, filepath='db/shenzhen-drive.osm', gephi=False, encoding='utf-8')
## the road network data is created by above code segment
shenzhen_road_network = ox.load_graphml('db/shenzhen-drive.osm')

# %%
_, sub_path = compute_shortest_path_len(shenzhen_road_network, road_path.iloc[i-1], road_path.iloc[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-518b8e453a2d> in <module>
# ----> 1 _, sub_path = compute_shortest_path_len(shenzhen_road_network, road_path.iloc[i-1], road_path.iloc[i])
#
# NameError: name 'compute_shortest_path_len' is not defined

# %%
(564713502, 2881809557) in shenzhen_road_network.edges
# Out:
# False

# %%
shenzhen_road_network.edges(2699455592, 2699455554)
# Out:
# OutMultiEdgeDataView([(2699455592, 2699455545), (2699455592, 2699455594), (2699455592, 2699455554), (2699455554, 2528889077), (2699455554, 2528889033), (2699455554, 2699455592)])

# %%
ox.plot_graph_route(shenzhen_road_network, 
                    [498877549,
 498877550,
 498877610,
 498877573,
 498877516,
 498857714,
 498867822,
 2529179619,
 2529179627,
 2529179584,
 2529179612,
 2529179611,
 1491845453,
 1491785786,
 1491785781,
 1491785778,
 1491785762,
 1491785756,
 1491785746,
 1491785693,
 1491785689,
 1491785664,
 1492127797,
 1491785596,
 1491785595,
 498877512,
 498877513,
 498491723,
 498489655,
 498491704,
 498491720,
 498877548])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
nx.shortest_path(shenzhen_road_network, 2743065171, 664959116, weight='length')
# Out:
# [2743065171,
#  1476460606,
#  499558934,
#  1116534624,
#  1116534593,
#  1116534765,
#  1116534558,
#  2529006353,
#  1116534545,
#  1116534754,
#  1116534583,
#  1116534709,
#  1116534740,
#  499558951,
#  1476460582,
#  1476460614,
#  2743065318,
#  2743065094,
#  2743065332,
#  664959160,
#  598164601,
#  598164738,
#  2743065218,
#  664959119,
#  664959117,
#  664959116]
